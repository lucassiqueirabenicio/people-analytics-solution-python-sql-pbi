# %% [markdown]
# 1 - Bibliotecas

# %%
import pandas as pd
import openpyxl
import os

# %% [markdown]
# 2 - Lendo arquivo dim_cargo.parquet

# %%
input_path = "../Data/2 - Bronze/dim_cargo.parquet"
output_path = "../Data/3 - Silver"


df = pd.read_parquet(input_path)

df
# Out:
#     Cód Cargo                           Cargo
# 0         249  AUXILIAR DE SERVIÇOS DE GERAIS
# 1         260              CONTROLER EM GERAL
# 2      001001                   DIRETOR GERAL
# 3         159               VENDEDOR EM GERAL
# 4         307    SUPERVISOR COMPRAS DE BLOCOS
# ..        ...                             ...
# 246       091  SUPERVISOR MARKETING COMERCIAL
# 247       084    RESPONSAVEL PROCESSO ARMAZEM
# 248    062001     GERENTE DE RECURSOS HUMANOS
# 249    037001  AUXILIAR LINHA DE PRODUÇÃO DES
# 250       090  SUPERVISOR COMPRAS ALMOXARIFAD
#
# [251 rows x 2 columns]

# %% [markdown]
# 3 - Renomeando colunas

# %%
df = df.rename(columns={'Cód Cargo': 'cod_cargo', 
                        'Cargo': 'cargo',
                      })

# %% [markdown]
# 4 - Tipando as colunas do data frame

# %%
tipos = { 
    'cod_cargo': 'Int64',
    'cargo': 'string',

}

df = df.astype(tipos)

# %% [markdown]
# 5 - Garantir que os IDs dos cargos sempre sejam numéricos

# %%
df['cod_cargo'] = pd.to_numeric(df['cod_cargo'], errors='coerce')

# %% [markdown]
# 6 - Padronizando os dados do tipo string para maiúsculo

# %%
colunas_texto = df.select_dtypes(include=['string']).columns

for col in colunas_texto:
    df[col] = df[col].str.upper().str.strip()

df
# Out:
#      cod_cargo                           cargo
# 0          249  AUXILIAR DE SERVIÇOS DE GERAIS
# 1          260              CONTROLER EM GERAL
# 2         1001                   DIRETOR GERAL
# 3          159               VENDEDOR EM GERAL
# 4          307    SUPERVISOR COMPRAS DE BLOCOS
# ..         ...                             ...
# 246         91  SUPERVISOR MARKETING COMERCIAL
# 247         84    RESPONSAVEL PROCESSO ARMAZEM
# 248      62001     GERENTE DE RECURSOS HUMANOS
# 249      37001  AUXILIAR LINHA DE PRODUÇÃO DES
# 250         90  SUPERVISOR COMPRAS ALMOXARIFAD
#
# [251 rows x 2 columns]

# %% [markdown]
# 7 - Enviando dim_cargo para a camada silver

# %%
df.to_parquet(os.path.join(output_path, "dim_cargo.parquet"), index=False)
